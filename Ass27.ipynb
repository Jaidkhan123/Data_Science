# %% [markdown]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.
#
# Ans->
# 1) Bar plot — sns.barplot() ...
# 2) Count plot — sns.countplot() ...
# 3) Box plots — sns.boxplot() ...
# 4) Violin plot — sns.violinplot() ...
# 5) Strip plot — sns.stripplot()

# %%
import seaborn as sns 
  
# reading the dataset 
df = sns.load_dataset('tips') 
  
# change the estimator from mean to
# standard deviation 
sns.barplot(x ='sex', y ='total_bill', data = df,  
            palette ='plasma')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
import seaborn as sns
  
# reading the dataset
df = sns.load_dataset('tips')
sns.violinplot(x='day', y='total_bill', data=df,
               hue='sex', split=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
import seaborn as sns
  
# reading the dataset
df = sns.load_dataset('tips')
  
sns.boxplot(x='day', y='total_bill', data=df, hue='smoker')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
import seaborn as sns
  
# reading the dataset
df = sns.load_dataset('tips')
sns.stripplot(x='day', y='total_bill', data=df,
              jitter=True, hue='smoker', dodge=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
import seaborn as sns 
  
# reading the dataset 
df = sns.load_dataset('tips') 
  
sns.countplot(x ='sex', data = df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %% [markdown]
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.
#
# Ans->

# %%
df = sns.load_dataset('fmri')
print(sns.lineplot(x="timepoint", y="signal", data=df , hue="event", style = "region"))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %% [markdown]
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.
#
# Ans->

# %%
df = sns.load_dataset('titanic')
sns.boxplot(x="pclass", y = "age", data=df)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x="pclass", y = "fare", data=df)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.
#
# Ans->

# %%
df = sns.load_dataset("diamonds")
# sns.displot(df.price)
sns.displot(data=df, x="price", hue="cut")

# %% [markdown]
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.
#
# Ans->

# %%
df= sns.load_dataset("iris")
sns.pairplot(data=df, hue="species")

# %% [markdown]
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.
#
# Ans->

# %%
import matplotlib.pyplot as plt
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights)
plt.title("Heatmap Flight Data")
plt.show()
# Out:
# /tmp/ipykernel_70/1461538549.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("month", "year", "passengers")
